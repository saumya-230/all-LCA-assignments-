# %%
list1 = [1, 2, 3, 4, 5]
tuple1 = (10, 20, 30, 40, 50)
dict1 = {"a":5 , "b":15 , "c":25 , "d":35}

print(list1)
print(tuple1)
print(dict1)

list1.append(6)
dict1["e"]=45
print("after adding:")
print(list1)
print(dict1)

list1.pop()
list1.remove(3) 
dict1.pop("d")
print("after removing:")
print(list1)
print(dict1)
# Out:
# [1, 2, 3, 4, 5]
# (10, 20, 30, 40, 50)
# {'a': 5, 'b': 15, 'c': 25, 'd': 35}
# after adding:
# [1, 2, 3, 4, 5, 6]
# {'a': 5, 'b': 15, 'c': 25, 'd': 35, 'e': 45}
# after removing:
# [1, 2, 4, 5]
# {'a': 5, 'b': 15, 'c': 25, 'e': 45}
